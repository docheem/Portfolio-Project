# %% [markdown]
# <a href="https://colab.research.google.com/github/docheem/Portfolio-Project/blob/main/1Gen_AI_ML_Architect_L7_Ads_DSE_Streaming_Services.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Compressing and Representing Information
#
# This project contain:
#
# - Implementation of AutoEncoder encoder/decoder
# - Latent space version
# - Sequential rewrite
# - Implementation VAE encoder (mu/logvar)
# - Reparameterization trick
# - Training VAE loop with KL + reconstruction
#
#
#
# Data Preparations

# %%
# !pip install genaibook

from datasets import load_dataset
import matplotlib as mpl
import torch
from torchvision import transforms
# Out:
# Collecting genaibook
#   Downloading genaibook-0.1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from genaibook) (1.12.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from genaibook) (0.2.1)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.12/dist-packages (from genaibook) (1.9.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from genaibook) (2.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from genaibook) (2.9.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from genaibook) (0.24.0+cpu)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from genaibook) (2.9.0+cpu)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (from genaibook) (1.5.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from genaibook) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from genaibook) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from genaibook) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from genaibook) (1.16.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from genaibook) (0.11.0)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from genaibook) (0.36.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from genaibook) (4.57.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from genaibook) (5.2.0)
# Collecting bitsandbytes (from genaibook)
#   Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: datasets[audio] in /usr/local/lib/python3.12/dist-packages (from genaibook) (4.0.0)
# Collecting jiwer (from genaibook)
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting evaluate (from genaibook)
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from genaibook) (0.25.1)
# Collecting compel (from genaibook)
#   Downloading compel-2.3.1-py3-none-any.whl.metadata (18 kB)
# Collecting mediapipe (from genaibook)
#   Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting controlnet-aux (from genaibook)
#   Downloading controlnet_aux-0.0.10-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from genaibook) (0.18.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->genaibook) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->genaibook) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate->genaibook) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->genaibook) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate->genaibook) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->genaibook) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->genaibook) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->genaibook) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->genaibook) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->genaibook) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->genaibook) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->genaibook) (2025.3.0)
# Requirement already satisfied: notebook>=6.5.7 in /usr/local/lib/python3.12/dist-packages (from compel->genaibook) (6.5.7)
# Requirement already satisfied: pyparsing~=3.0 in /usr/local/lib/python3.12/dist-packages (from compel->genaibook) (3.2.5)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->genaibook) (8.7.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers->genaibook) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers->genaibook) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers->genaibook) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->genaibook) (0.22.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->genaibook) (4.67.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from controlnet-aux->genaibook) (4.12.0.88)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from controlnet-aux->genaibook) (0.8.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from controlnet-aux->genaibook) (1.0.22)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from controlnet-aux->genaibook) (0.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets[audio]->genaibook) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets[audio]->genaibook) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets[audio]->genaibook) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets[audio]->genaibook) (0.70.16)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from datasets[audio]->genaibook) (0.13.1)
# Collecting torchcodec>=0.4.0 (from datasets[audio]->genaibook)
#   Downloading torchcodec-0.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer->genaibook) (8.3.1)
# Collecting rapidfuzz>=3.9.7 (from jiwer->genaibook)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/30/83/80d22997acd928eda7deadc19ccd15883904622396d6571e935993e0453a/rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->genaibook) (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->genaibook) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->genaibook) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->genaibook) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->genaibook) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->genaibook) (2.9.0.post0)
# Collecting absl-py~=2.3 (from mediapipe->genaibook)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting sounddevice~=0.5 (from mediapipe->genaibook)
#   Downloading sounddevice-0.5.3-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: flatbuffers~=25.9 in /usr/local/lib/python3.12/dist-packages (from mediapipe->genaibook) (25.9.23)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->genaibook) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->genaibook) (2025.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (3.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers->genaibook) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers->genaibook) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers->genaibook) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers->genaibook) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers->genaibook) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (1.2.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (6.5.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (26.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (25.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (5.9.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (7.4.9)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.5.7->compel->genaibook) (1.3.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->genaibook) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->genaibook) (4.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->genaibook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers->genaibook) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers->genaibook) (2.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->genaibook) (3.6.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice~=0.5->mediapipe->genaibook) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->genaibook) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->genaibook) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->genaibook) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->controlnet-aux->genaibook) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->controlnet-aux->genaibook) (2025.12.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (1.22.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice~=0.5->mediapipe->genaibook) (2.23)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client<8,>=5.3.4->notebook>=6.5.7->compel->genaibook) (0.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=6.5.7->compel->genaibook) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5.7->compel->genaibook) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=6.5.7->compel->genaibook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=6.5.7->compel->genaibook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=6.5.7->compel->genaibook) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=6.5.7->compel->genaibook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=6.5.7->compel->genaibook) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=6.5.7->compel->genaibook) (2.19.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=6.5.7->compel->genaibook) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=6.5.7->compel->genaibook) (4.25.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook>=6.5.7->compel->genaibook) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=6.5.7->compel->genaibook) (25.1.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook>=6.5.7->compel->genaibook) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook>=6.5.7->compel->genaibook) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook>=6.5.7->compel->genaibook) (0.2.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5.7->compel->genaibook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5.7->compel->genaibook) (1.4.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->compel->genaibook)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->compel->genaibook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->compel->genaibook) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->compel->genaibook) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.5.7->compel->genaibook) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5.7->compel->genaibook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5.7->compel->genaibook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5.7->compel->genaibook) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (2.14.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.5.7->compel->genaibook) (2.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.5.7->compel->genaibook) (0.8.5)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (1.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.5.7->compel->genaibook) (0.2.14)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5.7->compel->genaibook) (1.4.0)
# Downloading genaibook-0.1.1-py3-none-any.whl (12 kB)
# Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 11.4 MB/s eta 0:00:00
# Downloading compel-2.3.1-py3-none-any.whl (36 kB)
# Downloading controlnet_aux-0.0.10-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 16.6 MB/s eta 0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.7 MB/s eta 0:00:00
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 93.4 MB/s eta 0:00:00
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 14.3 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 80.7 MB/s eta 0:00:00
# Downloading sounddevice-0.5.3-py3-none-any.whl (32 kB)
# Downloading torchcodec-0.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.5 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.1 MB/s eta 0:00:00
# Installing collected packages: torchcodec, rapidfuzz, jedi, absl-py, sounddevice, jiwer, mediapipe, bitsandbytes, evaluate, controlnet-aux, compel, genaibook
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# Successfully installed absl-py-2.3.1 bitsandbytes-0.49.0 compel-2.3.1 controlnet-aux-0.0.10 evaluate-0.4.6 genaibook-0.1.1 jedi-0.19.2 jiwer-4.0.0 mediapipe-0.10.31 rapidfuzz-3.14.3 sounddevice-0.5.3 torchcodec-0.9.1

# %%
mydata = load_dataset("mnist")
mydata
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# mnist/train-00000-of-00001.parquet:   0%|          | 0.00/15.6M [00:00<?, ?B/s]
# mnist/test-00000-of-00001.parquet:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 60000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
from genaibook.core import show_images
show_images(mydata["train"]["image"][:3])

# %%
show_images(mydata["train"]["image"][:5])

# %%
import matplotlib as mpl

mpl.rcParams["image.cmap"] = "gray_r"


show_images(mydata["train"]["image"][:4])

# %% [markdown]
# #Creating a PyTorch DataLoader
#
# To prepare the training data.
#
# We will transform our images to Pytorch Tensors

# %%
from torchvision import transforms


def mnist_to_tensor(samples):

  t = transforms.ToTensor()

  samples["image"] = [t(image) for image in samples["image"]]

  return samples

mydata = mydata.with_transform(mnist_to_tensor)

mydata["train"] = mydata["train"].shuffle(seed=1337)

# %%
x = mydata["train"]["image"][0]
x.min(), x.max()
# Out:
# (tensor(0.), tensor(1.))

# %% [markdown]
# All images have the same size, and
# therefore, all tensors have the same shape,

# %%
show_images(mydata["train"]["image"][0])

# %%
from torch.utils.data import DataLoader

bs = 64

train_dataloader = DataLoader(mydata["train"]["image"],

                              batch_size=bs)

# %% [markdown]
# # Streaming services like Netflix trains encoders + decoders so:
# - Encoders embed ad creatives in  semantic space
# - Decoders generate creative variations from those embeddings

# %% [markdown]
# # Encoder Implementation
# The encoder extracts semantic embeddings used for ad search, ranking, similarity, and conditioning generative models.
#
# The encoder is designed to accept any number of channels — meaning it also works for: RGB ad, video frames, thumbnails, and Creative assets.

# %%
# Importing the nn (neural network) module from PyTorch’s torch library.
from torch import nn

# %%
# defining a function for the encoder
def conv_block(in_channels,

               out_channels,

               kernel_size = 4,

               stride = 2,

               padding = 1):


  return nn.Sequential(nn.Conv2d(in_channels,                 # number of channels coming in

                                 out_channels,                # how many learn filters maps to create

                                 kernel_size = kernel_size,   # size of the convolution filter

                                 stride = stride,             # how far we move the filter at each step (skip 2 pixels at a time)

                                 padding = padding,           # how many pixels of zero-padding to add around the border.
                                 ),

                       nn.BatchNorm2d(out_channels),          # Adds a 2D batch normalization layer that normalizes each of the out_channels feature maps.

                       nn.ReLU(),                             # keep positive signals, drop negative ones. This lets the network learn complex patterns, not just straight lines.”
                       )

# %% [markdown]
# what does an encoder do?
#
# An encoder converts ad creatives into dense semantic vectors used for search, ranking, safety, and generative models.

# %%
# Architecting the Encoder

class Encoder(nn.Module):                     # This is the model that compresses a high-dimensional creative asset (image) into a low-dimensional semantic vector

  def __init__(self, in_channels):            # Initializes the encoder with the number of input channels.

    super().__init__()

    self.conv1 = conv_block(in_channels, 128) # The model begins by learning edge detectors, textures, and simple patterns.

    self.conv2 = conv_block(128, 256)         # The encoder now learns mid-level visual features

    self.conv3 = conv_block(256, 512)         # Now the encoder is learning semantic structures such as product boundaries, human faces, or pose components

    self.conv4 = conv_block(512, 1024)        # The entire image becomes a 1×1×1024 tensor. This is the high-level abstract “meaning.”

    self.linear = nn.Linear(1024, 16)         # This is the latent vector. The compact representation the AutoEncoder learns.



  # FORWARD PASS (THE ACTUAL COMPUTATION)
  def forward(self, x):

      x = self.conv1(x)  # (batch size, 128, 14, 14)
      x = self.conv2(x)  # (bs, 256, 7, 7)
      x = self.conv3(x)  # (bs, 512, 3, 3)
      x = self.conv4(x)  # (bs, 1024, 1, 1)

      # Keep batch size intact.
      x = self.linear(x.flatten(start_dim=1))  # (bs, 16)

      return x


# The final convolution produces a 1024-dimensional semantic embedding that captures the meaning of the creative.

# %% [markdown]
# What did we built?
#
# We have built a convolutional encoder using a series of Conv → BatchNorm → ReLU blocks that progressively reduce spatial resolution while increasing channel depth. Each layer extracts increasingly abstract features. After reaching a 1024-channel bottleneck at 1×1 resolution, we flatten the representation and project it into a 16-dimensional latent vector. This serves as the compact embedding for similarity search, clustering, or generative reconstruction.

# %%
# verifying that we can run our input images through the encoder.
# Check the shape of one image

mydata["train"]["image"][0].shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# Creating a new dimension with
# PyTorch’s None indexing, by selecting and put a single image inside a batch

# %%
# Set how many input channels we have
in_channels = 1

# Put one image into a batch
x = mydata["train"]["image"][0][None, :]

# Create the encoder and switch to eval/testing mode
encoder = Encoder(in_channels).eval()

# Run the image through the encoder
# We successfully compressed 784 pixels, 28 × 28 images → 16 numbers.
encoded = encoder(x)
encoded.shape
# Out:
# torch.Size([1, 16])

# %% [markdown]
# The encoder model  have successfully converted  28 × 28 images (784 pixels each) into vectors with just 16 numbers. If we can train it effectively, the representations computed by the encoder will have much lower dimensionality than the original pixel data.

# %%
# Remember the representations are currently meaningless, as the model is yet to
# be trained
encoded
# Out:
# tensor([[-0.0218, -0.0238,  0.0237,  0.0078,  0.0175, -0.0115,  0.0212, -0.0221,
#          -0.0152,  0.0255, -0.0060,  0.0256, -0.0024, -0.0005,  0.0250,  0.0391]],
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# Test on a whole batch of 64 images

# %%
batch = next(iter(train_dataloader))

encoded = Encoder(in_channels=1)(batch)

batch.shape, encoded.shape
# (torch.Size([64, 1, 28, 28]), torch.Size([64, 16]))
# Out:
# (torch.Size([64, 1, 28, 28]), torch.Size([64, 16]))

# %% [markdown]
# #Decoder
#
# Our decoder takes the small latent vector — essentially the compressed meaning of a creative — and reconstructs a full image by first expanding it through a linear layer into a small 4×4 feature grid, then using a series of transposed convolutions to gradually increase spatial resolution while reducing channel depth.
#
# This mirrors how generative models like Stable Diffusion upscale latent representations into full-resolution ads.

# %%
def conv_transpose_block(    # Transposed convolution expands the image resolution. Only use by Decoder

    in_channels,

    out_channels,

    kernel_size = 3,

    stride = 2,

    padding = 1,

    output_padding = 0,      # When you “stretch” an image, you sometimes need a tiny patch to make the math line up → that’s output_padding.

    with_act = True,         # option to turn on/off activation (with with_act=False).

):
    modules = [

        nn.ConvTranspose2d(

            in_channels,

            out_channels,

            kernel_size = kernel_size,

            stride = stride,

            padding = padding,

            output_padding = output_padding,

        ),
    ]

    if with_act:  # Controling this will be handy later

        modules.append(nn.BatchNorm2d(out_channels))

        modules.append(nn.ReLU())

    return nn.Sequential(*modules)

# %% [markdown]
# This is how Stable Diffusion decoders start:
#
# - Tiny latent → dense feature grid → upscale to full image.

# %%
class Decoder(nn.Module):

    def __init__(self, out_channels):

        super().__init__()

        self.linear = nn.Linear(16, 1024 * 4 * 4)  # note it's reshaped in forward

        self.t_conv1 = conv_transpose_block(1024, 512)

        self.t_conv2 = conv_transpose_block(512, 256, output_padding=1)

        self.t_conv3 = conv_transpose_block(256, out_channels, output_padding=1)

    def forward(self, x):

        bs = x.shape[0]

        x = self.linear(x)  # (bs, 1024*4*4)

        x = x.reshape((bs, 1024, 4, 4))  # (bs, 1024, 4, 4)
        x = self.t_conv1(x)  # (bs, 512, 7, 7)
        x = self.t_conv2(x)  # (bs, 256, 14, 14)
        x = self.t_conv3(x)  # (bs, 1, 28, 28)

        return x

# %% [markdown]
# #Trainning
#
# We are teaching the system to represent images compactly AND decode them.
#
# The AutoEncoder succeeds when:
# - Decoder learns to reconstruct images well
# - Encoder learns to compress images to meaningful features
# - Latent vectors hold semantic information
#
#
# image → Encoder → latent → Decoder → reconstructed image
#
# This training style is how Netflix learns:
#
# - Creative embeddings
# - Brand-safe features
# - Ad-style representation
# - Latent spaces for diffusion models

# %% [markdown]
# This is foundational for:
# - Creative ranking
# - Semantic search
# - Generative ads
# - Multimodal alignment
# - Ad similarity scoring

# %% [markdown]
# If training works:
#
# - Encoders produce meaningful creative embeddings
# - Decoders generate realistic ad frames
# - Latents encode brand identity, color palette, product layout, etc.

# %% [markdown]
# Once trained:
#
# - We can use just the encoder → to get latent vectors for any image
# - We can use just the decoder → to generate new images from random latent vectors
# - We can use them together → for reconstruction
#
# This makes AutoEncoders extremely versatile.

# %%
class AutoEncoder(nn.Module):

    def __init__(self, in_channels):

        super().__init__()
        self.encoder = Encoder(in_channels)   # the Encoder → compresses images to latent vectors

        self.decoder = Decoder(in_channels)   # the Decoder → expands latent vectors back to images

    def encode(self, x):
        return self.encoder(x)

    def decode(self, x):
        return self.decoder(x)

    def forward(self, x):
        return self.decode(self.encode(x))   # Return reconstructed image

# %% [markdown]
# This training loop above:
# - Load a batch of images
# - Send them through AutoEncoder
# - Compute reconstruction loss
# - Backpropagate
# - Update weights
# - Repeat for all batches and all epochs
#
# Trainning Path
# image → encoder → latent(16) → decoder → reconstructed image

# %%
model = AutoEncoder(1)

# %% [markdown]
# AutoEncoders are the backbone of Netflix’s for:
# - Creative reconstruction
# - Latent diffusion
# - Semantic embedding
# - Ad creative generation
# - Multimodal alignment pipelines
#
#
# The AutoEncoder class wraps an encoder and decoder into a single PyTorch module. The encoder compresses images into a latent vector, the decoder reconstructs them, and forward() passes inputs through both to minimize reconstruction error during training. It also exposes separate encode and decode methods, allowing the encoder or decoder to be used independently — critical for tasks like creative embeddings, reconstruction, and generative pipelines.

# %% [markdown]
# We have created a simple training loop that repeatedly goes through
# the training data and uses a constant learning rate.

# %%
import torchsummary

torchsummary.summary(model, input_size=(1, 28, 28), device="cpu")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 14, 14]           2,176
#        BatchNorm2d-2          [-1, 128, 14, 14]             256
#               ReLU-3          [-1, 128, 14, 14]               0
#             Conv2d-4            [-1, 256, 7, 7]         524,544
#        BatchNorm2d-5            [-1, 256, 7, 7]             512
#               ReLU-6            [-1, 256, 7, 7]               0
#             Conv2d-7            [-1, 512, 3, 3]       2,097,664
#        BatchNorm2d-8            [-1, 512, 3, 3]           1,024
#               ReLU-9            [-1, 512, 3, 3]               0
#            Conv2d-10           [-1, 1024, 1, 1]       8,389,632
#       BatchNorm2d-11           [-1, 1024, 1, 1]           2,048
#              ReLU-12           [-1, 1024, 1, 1]               0
#            Linear-13                   [-1, 16]          16,400
#           Encoder-14                   [-1, 16]               0
#            Linear-15                [-1, 16384]         278,528
#   ConvTranspose2d-16            [-1, 512, 7, 7]       4,719,104
#       BatchNorm2d-17            [-1, 512, 7, 7]           1,024
#              ReLU-18            [-1, 512, 7, 7]               0
#   ConvTranspose2d-19          [-1, 256, 14, 14]       1,179,904
#       BatchNorm2d-20          [-1, 256, 14, 14]             512
#              ReLU-21          [-1, 256, 14, 14]               0
#   ConvTranspose2d-22            [-1, 1, 28, 28]           2,305
#       BatchNorm2d-23            [-1, 1, 28, 28]               2
#              ReLU-24            [-1, 1, 28, 28]               0
#           Decoder-25            [-1, 1, 28, 28]               0
# ================================================================
# Total params: 17,215,635
# Trainable params: 17,215,635
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.86
# Params size (MB): 65.67
# Estimated Total Size (MB): 68.54
# ----------------------------------------------------------------

# %% [markdown]
# We have trained an AutoEncoder end-to-end using a reconstruction loss.
# The encoder learns a compressed latent representation (16-D),
# and the decoder learns to reconstruct the input image from this latent.
# The summary shows how convolutional downsampling and transposed convolutional upsampling form a symmetric bottleneck architecture capable of learning meaning-rich embeddings.
# This setup is foundational for diffusion models, creative generation, and ad-semantic understanding
#
# Next we will:
# - Load a batch from the DataLoader.
# - Get the model predictions.
# - Calculate the loss with respect to the original images.
# - Perform an optimizer step to update the model weights.

# %%
import torch
from matplotlib import pyplot as plt
from torch.nn import functional as F
from tqdm.notebook import tqdm, trange
from genaibook.core import get_device

# %%
num_epochs = 2

lr = 1e-4


device = get_device('cpu')                                                              # Model must live on CPU or GPU so it can work.

model = model.to(device)



optimizer = torch.optim.AdamW(model.parameters(), lr = lr,  eps=1e-5)                   # AdamW updates the weights of the neural network.




losses = []                                                                            # List to store the loss values for plotting. We’ll store how “bad” the reconstruction is over time.


for _ in (progress := trange(num_epochs,desc = "Training")):                           # Repeat training 10 times



    for _, batch in (inner := tqdm(enumerate(train_dataloader), total=len(train_dataloader))): # Go through all the training images in small batches


        batch = batch.to(device)                                                       # Move batch to device


        # Pass images through model
        preds = model(batch)

        # Compare the decoder output to the original input pixel by pixel.
        # Computing reconstruction loss
        loss = F.mse_loss(preds, batch)


        # Log the loss and store for plotting
        inner.set_postfix(loss=f"{loss.cpu().item():.3f}")

        # Save the loss
        losses.append(loss.item())



        # Backpropagation, computes gradients = how much each weight contributed to the error
        loss.backward()

        # Update weights, Optimizer nudges each weight slightly to reduce future errors
        optimizer.step()

        # reset gradient, Clears previous gradients so they don’t accumulate.
        optimizer.zero_grad()

    # Update outer progress bar, Shows final loss for the epoch.
    progress.set_postfix(loss = f"{loss.cpu().item():.3f}")
# Out:
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]

# %% [markdown]
# This training the backbone of:
#
# - Creative embedding models (like CLIP)
# - Ad similarity scoring
# - Brand-safety models
# - Latent diffusion (SD-based ad generation)
# - Creative optimization loops
# - Multimodal ad/copy alignment
#
# This training loop is identical to what Netflix teams use to train:
#
# - VAEs
# - Latent diffusion models
# - Multimodal embeddings
# - Semantic encoders for ad intelligence

# %%
plt.plot(losses)
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("AutoEncoder – Training Loss Curve")
plt.show()

# %% [markdown]
# After training a creative model, Netflix tests using held-out creatives:
#
# - unseen ads
# - unseen thumbnails
# - unseen product photos
#
# This ensures the model generalized, not memorized.

# %% [markdown]
# #Evaluation mode
#
#
#
# We can actually see what the AutoEncoder learned.
#
# Switches the AutoEncoder to evaluation mode:
# - Turns off Dropout
# - BatchNorm uses stored running averages
# - No gradients
# - Stable inference

# %%
# First we create a DataLoader around the test set to have iur Autoencoder
# evaluate 16 images at a time

eval_bs = 16

eval_dataloader = DataLoader(mydata["test"]["image"],

                             batch_size = eval_bs)

# %% [markdown]
# Eval mode = Production inference mode
# Used for:
# - Generating ad previews
# - Evaluating creative embeddings
# - Running classifiers on creatives
# - Brand safety checks

# %%
# 2 Put the model in eval mode
model.eval()
# Out:
# AutoEncoder(
#   (encoder): Encoder(
#     (conv1): Sequential(
#       (0): Conv2d(1, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv4): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (linear): Linear(in_features=1024, out_features=16, bias=True)
#   )
#   (decoder): Decoder(
#     (linear): Linear(in_features=16, out_features=16384, bias=True)
#     (t_conv1): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (t_conv2): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (t_conv3): Sequential(
#       (0): ConvTranspose2d(256, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
# )

# %% [markdown]
# Let’s once again load the trained model and look at some reconstructions

# %%
# 3 disable gradient computations which mean
# No gradient tracking, No backward pass, Faster and safer.
with torch.inference_mode():


    # 4. Get one evaluation batch
    eval_batch = next(iter(eval_dataloader))


    # 5. Generate reconstructed images
    # This is latent interpretability
    predicted = model(eval_batch.to(device)).cpu()

# %% [markdown]
# This is how Netflix checks:
#
# - Creative reconstruction quality
# - embedding → decoder consistency
# - What latent space is preserving
#
# It reveals:
#
# - what features the model learns
# - what digits it confuses
# - what variations it can generate
#
# This is latent interpretability.

# %% [markdown]
# # Compare originals with predictions
#
# We create a single tensor:
#
# - First 16 images = originals
# - Next 16 images = reconstructions

# %%
# Tensor created for preds and original
batch_vs_preds = torch.cat((eval_batch, predicted))

show_images(batch_vs_preds,

            imsize = 1,

            nrows = 2)

# %% [markdown]
# This is how Netflix teams visually inspect:
#
# - Reconstruction quality
# - Creative realism
# - Latent compression loss
# - Feature preservation
# - Distortion of brand elements
#
# This is essential for generative ad pipelines — especially training VAEs & diffusion models.

# %% [markdown]
# #Latent Space
#
# We will implement an identical Encoder, decoder and AE
#
# We will transform our AutoEncoder from a simple compressor into a latent representation research tool!
#
# By using sigmoid as the activation function, we ensure that the output after each layer lies within the
# range (0, 1), the same range the input images use.

# %%
# Plot of the ReLU versus the sigmoid function.
def plot_activation_fn(fn, name):

    x = torch.linspace(-5, 5, 100)

    y = fn(x)

    plt.plot(x, y, label = name)

    plt.legend()



plt.title("Activation Functions")

plot_activation_fn(F.relu, "ReLU")

plot_activation_fn(F.sigmoid, "Sigmoid")

# %%
class Encoder(nn.Module):

    def __init__(self, in_channels, latent_dims):

        super().__init__()

        self.conv_layers = nn.Sequential(

            conv_block(in_channels, 128),
            conv_block(128, 256),
            conv_block(256, 512),
            conv_block(512, 1024),
        )
        self.linear = nn.Linear(1024, latent_dims)


    def forward(self, x):

        bs = x.shape[0]

        x = self.conv_layers(x)

        x = self.linear(x.reshape(bs, -1))
        return x

# %% [markdown]
# At Netflix this mirrors production architectures:
#
# - Modular blocks
# - configurable depth
# - easy to experiment
# - important for rapid prototyping
#
# Netflix Ads team needs to experiment with:
#
# - Different encoder depths
# - Different bottlenecks
# - Large-scale creative datasets
#
# This refactor makes that easier.

# %%
class Decoder(nn.Module):

  def __init__(self, out_channels, latent_dims):

            super().__init__()

            self.linear = nn.Linear(latent_dims, 1024 * 4 * 4)

            self.t_conv_layers = nn.Sequential(

                conv_transpose_block(1024, 512),

                conv_transpose_block(512, 256, output_padding = 1),

                conv_transpose_block(256, out_channels,

                                     output_padding = 1,

                                     with_act = False ),
                )

            self.sigmoid = nn.Sigmoid()


  def forward(self, x):

    bs = x.shape[0]

    x = self.linear(x)

    x = x.reshape((bs, 1024, 4, 4))

    x = self.t_conv_layers(x)

    x = self.sigmoid(x)
    return x

# %%
class AutoEncoder(nn.Module):

  def __init__(self, in_channels, latent_dims):

            super().__init__()

            self.encoder = Encoder(in_channels, latent_dims)

            self.decoder = Decoder(in_channels, latent_dims)

  def encode(self, x): return self.encoder(x)

  def decode(self, x): return self.decoder(x)

  def forward(self, x):

    return self.decode(self.encode(x))

# %% [markdown]
# The training loop is the same as before, but we put it inside a function to reuse it and call it whenever needed

# %%
def train(model, num_epochs=2, lr=1e-2):

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, eps=1e-5)

    model.train()  # Put model in training mode

    losses = []

    for _ in (progress := trange(num_epochs, desc="Training")):

        for _, batch in (

            inner := tqdm(

                enumerate(train_dataloader), total=len(train_dataloader)
            )
        ):
            batch = batch.to(device)

            # Pass through the model and obtain another set of images
            preds = model(batch)

            # Compare the prediction with the original images
            loss = F.mse_loss(preds, batch)

            # Display loss and store for plotting
            inner.set_postfix(loss=f"{loss.cpu().item():.3f}")

            losses.append(loss.item())


            # Update the model parameters with the optimizer based on this loss
            loss.backward()

            optimizer.step()

            optimizer.zero_grad()

        progress.set_postfix(loss=f"{loss.cpu().item():.3f}", lr=f"{lr:.0e}")

    return losses

# %%
ae_model = AutoEncoder(in_channels=1, latent_dims=2)
ae_model.to(device)
# Out:
# AutoEncoder(
#   (encoder): Encoder(
#     (conv_layers): Sequential(
#       (0): Sequential(
#         (0): Conv2d(1, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (linear): Linear(in_features=1024, out_features=2, bias=True)
#   )
#   (decoder): Decoder(
#     (linear): Linear(in_features=2, out_features=16384, bias=True)
#     (t_conv_layers): Sequential(
#       (0): Sequential(
#         (0): ConvTranspose2d(1024, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (1): Sequential(
#         (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(256, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       )
#     )
#     (sigmoid): Sigmoid()
#   )
# )

# %%
losses = train(ae_model)
# Out:
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2983505333.py in <cell line: 0>()
# ----> 1 losses = train(ae_model)
#
# /tmp/ipython-input-340897058.py in train(model, num_epochs, lr)
#      31
#      32             # Update the model parameters with the optimizer based on this loss
# ---> 33             loss.backward()
#      34
#      35             optimizer.step()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
plt.plot(losses)
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training Loss Curve (two latent dimensions)")
plt.show()

# %% [markdown]
# We restructured the AutoEncoder to make the latent dimensionality configurable, enabling both higher compression and visualization of the latent space. We replaced the final activation with sigmoid to match the pixel distribution, modularized the architecture via nn.Sequential, and wrapped training into a reusable function. These changes transform the AutoEncoder into an analysis tool that reveals how different inputs are represented in latent space — a core concept behind generative modeling and multimodal systems like those used in Netflix Ads.

# %% [markdown]
# This is how Netflix evaluates:
# - creative clustering
# - semantic spaces
# - ad similarity maps
# - latent interpolation quality
#
# They often reduce dimensions to visualize:
#
# - Clusters of ad creatives
# - Clusters of product categories
# - Emotional tone
# - Brand style

# %% [markdown]
# #Visualizing the Latent Space

# %%
images_labels_dataloader = DataLoader(mydata["test"], batch_size=512)

# %%
import pandas as pd

df = pd.DataFrame(
    {
        "x": [],
        "y": [],
        "label": [],
    }
)

for batch in tqdm(
    iter(images_labels_dataloader), total=len(images_labels_dataloader)
):
    encoded = ae_model.encode(batch["image"].to(device)).cpu()
    new_items = {
        "x": [t.item() for t in encoded[:, 0]],
        "y": [t.item() for t in encoded[:, 1]],
        "label": batch["label"],
    }
    df = pd.concat([df, pd.DataFrame(new_items)], ignore_index=True)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(10, 8))

for label in range(10):

  points = df[df["label"] == label]

  plt.scatter(points["x"], points["y"], label=label, marker=".")

  plt.legend();

# %% [markdown]
# Let’s see an example of image generation with the decoder

# %%
N = 16 # We'll generate 16 points

z = torch.rand((N, 2)) * 8 - 4

# %% [markdown]
# #Latent Space Visualization
#
# Visualizing the generated latent samples overlayed on top of the latent space representation we showed befor

# %%
plt.figure(figsize=(10, 8))

for label in range(10):

  points = df[df["label"] == label]

  plt.scatter(points["x"],
              points["y"],
              label=label,
              marker=".")

plt.scatter(z[:, 0],
            z[:, 1],
            label="z",
            marker="s",
            color="black")

plt.legend();

# %% [markdown]
# Let’s ask the decoder to generate images from the latent samples we just created.

# %%
ae_decoded = ae_model.decode(z.to(device))

show_images(ae_decoded.cpu(),

            imsize = 1,

            nrows = 1,

            suptitle = "AutoEncoder")

# %% [markdown]
# #Variational AutoEncoders
#
#
# Using a a multivariate Gaussian
#
# - Isotropic Gaussian
# - Diagonal covariance
#
# The VAE has two goals: reconstruct the image (like before) and Shape the latent space, as well as, forces the latent space to be:
#
# - Smooth
# - Continuous
# - Gaussian-shaped distribution
# - Evenly distributed
# - Interpolatable (good for generation)

# %%
# Lets Build the Encoder.We will not build a decoder, it stay the same.
# We will simply call it from the last sessions

class VAEEncoder(nn.Module):

    def __init__(self, in_channels, latent_dims):
        super().__init__()

        # extract high-level features from the image
        # Then compress the image into a 1024-feature representation.
        self.conv_layers = nn.Sequential(
            conv_block(in_channels, 128),
            conv_block(128, 256),
            conv_block(256, 512),
            conv_block(512, 1024),
        )

        # Define fully connected layers for mean and log-variance

        # learn the center of the Gaussian
        self.mu = nn.Linear(1024, latent_dims)

        # Learn the spread of the Gaussian
        self.logvar = nn.Linear(1024, latent_dims)

    def forward(self, x):

        bs = x.shape[0]

        x = self.conv_layers(x)
        x = x.reshape(bs, -1)

        mu = self.mu(x)
        logvar = self.logvar(x)

        return (mu, logvar)

# %%
class VAE(nn.Module):

    def __init__(self, in_channels, latent_dims):

        super().__init__()

        self.encoder = VAEEncoder(in_channels, latent_dims)
        self.decoder = Decoder(in_channels, latent_dims)

    def encode(self, x):

        # Returns mu, log_var
        return self.encoder(x)

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        # Obtain parameters of the normal (Gaussian) distribution
        mu, logvar = self.encode(x)

        # Sample from the distribution
        std = torch.exp(0.5 * logvar)
        z = self.sample(mu, std)

        # Decode the latent point to pixel space
        reconstructed = self.decode(z)

        # Return the reconstructed image, and also the mu and logvar
        # so we can compute a distribution loss
        return reconstructed, mu, logvar

    def sample(self, mu, std):
        # Reparametrization trick
        # Sample from N(0, I), translate and scale
        eps = torch.randn_like(std)
        return mu + eps * std

# %% [markdown]
# Sampling from the Encoder Distribution

# %%
def vae_loss(batch, reconstructed, mu, logvar):

    bs = batch.shape[0]

    # Reconstruction loss from the pixels - 1 per image
    reconstruction_loss = F.mse_loss(

        reconstructed.reshape(bs, -1),

        batch.reshape(bs, -1),

        reduction="none",

    ).sum(dim=-1)

    # KL-divergence loss, per input image
    kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp(), dim=-1)

    # Combine both losses and get the mean across images
    loss = (reconstruction_loss + kl_loss).mean(dim=0)

    return (loss, reconstruction_loss, kl_loss)

# %% [markdown]
# Traiining The VAE, We're using the same scripts from the last session.

# %%
def train_vae(model, num_epochs = 2, lr = 1e-4):

    model = model.to(device)
    losses = {

        "loss": [],
        "reconstruction_loss": [],
        "kl_loss": [],
    }

    model.train()

    optimizer = torch.optim.AdamW(model.parameters(),

                                  lr = lr, eps = 1e-5)

    for _ in (progress := trange(num_epochs, desc="Training")):

        for _, batch in (

            inner := tqdm(

                enumerate(train_dataloader),
                total = len(train_dataloader)
            )
        ):
            batch = batch.to(device)

            # Pass through the model
            reconstructed, mu, logvar = model(batch)

            # Compute the losses
            loss, reconstruction_loss, kl_loss = vae_loss(
                batch, reconstructed, mu, logvar
            )

            # Display loss and store for plotting
            inner.set_postfix(loss=f"{loss.cpu().item():.3f}")

            losses["loss"].append(loss.item())

            losses["reconstruction_loss"].append(

                reconstruction_loss.mean().item()
            )
            losses["kl_loss"].append(kl_loss.mean().item())

            # Update model parameters based on the total loss
            optimizer.zero_grad()

            loss.backward()

            optimizer.step()

        progress.set_postfix(loss=f"{loss.cpu().item():.3f}", lr=f"{lr:.0e}")
    return losses

# %%
vae_model = VAE(in_channels = 1,

                latent_dims=2)

# %%
losses = train_vae(vae_model,
                   num_epochs = 2,
                   lr = 1e-4)
# Out:
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]

# %%
for k, v in losses.items():
    plt.plot(v, label=k)
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2913094565.py in <cell line: 0>()
# ----> 1 for k, v in losses.items():
#       2     plt.plot(v, label=k)
#       3 plt.legend();
#
# AttributeError: 'list' object has no attribute 'items'

# %% [markdown]
#  Reconstructing some images and visualize the results of VAE reconstructions from MNIST samples:

# %%
vae_model.eval()

with torch.inference_mode():

  eval_batch = next(iter(eval_dataloader))

  predicted, mu, logvar = (v.cpu() for v in vae_model(eval_batch.to(device)))


batch_vs_preds = torch.cat((eval_batch, predicted))
show_images(batch_vs_preds, imsize=1, nrows=2)

# %% [markdown]
# Visualisations

# %%
df = pd.DataFrame(
    {
        "x": [],
        "y": [],
        "label": [],
    }
)

for batch in tqdm(

    iter(images_labels_dataloader),

    total=len(images_labels_dataloader)
):
    mu, _ = vae_model.encode(batch["image"].to(device))
    mu = mu.to("cpu")
    new_items = {
        "x": [t.item() for t in mu[:, 0]],
        "y": [t.item() for t in mu[:, 1]],
        "label": batch["label"],
    }
    df = pd.concat([df, pd.DataFrame(new_items)], ignore_index=True)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(10, 8))

for label in range(10):
    points = df[df["label"] == label]
    plt.scatter(points["x"], points["y"], label=label, marker=".")

plt.legend();

# %% [markdown]
# Sampling random data from the distribution and, hopefully, obtain images that resemble our input dataset

# %%
z = torch.normal(0, 1, size=(10, 2))

ae_decoded = ae_model.decode(z.to(device))

vae_decoded = vae_model.decode(z.to(device))

# %%
show_images(ae_decoded.cpu(), imsize=1, nrows=1)

show_images(vae_decoded.cpu(), imsize=1, nrows=1)

# %%
import numpy as np

with torch.inference_mode(): inputs = []

for y in np.linspace(-2, 2, 10): inputs.append([-0.8, y])


z = torch.tensor(inputs, dtype=torch.float32).to(device)
decoded = vae_model.decode(z)


show_images(decoded.cpu(), imsize=1, nrows=1)

# %% [markdown]
# This is a visual representation of what the model learned,

# %%
inputs = []

for x in np.linspace(-2, 2, 20):

  for y in np.linspace(-2, 2, 20):

    inputs.append([x, y])

z = torch.tensor(inputs, dtype=torch.float32).to(device)
decoded = vae_model.to(device).decode(z)

show_images(decoded.cpu(), imsize=0.4, nrows=20)

# %% [markdown]
# VAEs learn probability distributions (mean + variance) for each latent dimension, use reparametrization to sample differentiably from them, and output log-variance instead of variance for numerical stability.
